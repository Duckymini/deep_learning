# %% [markdown]
# # FAISS Index Builder using Sentence-BERT (SBERT)
#
# Builds three FAISS vector database for the retriever using `sentence-transformers/all-mpnet-base-v2`.
#
# **Outputs:**
# ```
# corpus/index/
#   vdb_example.faiss    (~67k vectors)
#   vdb_knowledge.faiss   (~41k vectors)
#   vdb_full.faiss        (~108k vectors)
#   lookup_example.json
#   lookup_knowledge.json
#   lookup_full.json
# ```

# %% [markdown]
# ## 1. Imports

# %%
import os
import json
from pathlib import Path
import numpy as np
import pandas as pd
import torch
import faiss
from transformers import AutoTokenizer, AutoModel, AutoModelForSequenceClassification
from tqdm import tqdm

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %% [markdown]
# ## 2. Configurations
#
# Here we define the paths to save the indexes

# %%
CORPUS_DIR = Path("../../corpus")
INDEX_DIR  = CORPUS_DIR / "index"
CHUNKS_DIR = CORPUS_DIR / "chunks"

# %% [markdown]
# ## 3. Load Chunks
#
# Load both source .csv chunks files to vectorize:
# - `chunks_example.csv`
# - `chunks_knowledge.csv`
#
# Three source tuples are prepared for the indexing loop: `example`, `knowledge` and `full` taht combine both.

# %%
DOCUMENTS_ID_OFFSET = 100_000  # training IDs: 0-99999 and document IDs: 100000+ to provide overlaps

df_example   = pd.read_csv(CHUNKS_DIR / "chunks_example.csv")[["chunk_id", "text"]]
df_knowledge = pd.read_csv(CHUNKS_DIR / "chunks_knowledge.csv")[["chunk_id", "text"]]
df_full = pd.concat([
    df_example,
    df_knowledge.assign(chunk_id=df_knowledge["chunk_id"] + DOCUMENTS_ID_OFFSET),
], ignore_index=True)

SOURCES = {
    "example":  (df_example["text"].tolist(),  df_example["chunk_id"].to_numpy(dtype="int64")),
    "knowledge": (df_knowledge["text"].tolist(), df_knowledge["chunk_id"].to_numpy(dtype="int64")),
    "full":      (df_full["text"].tolist(),       df_full["chunk_id"].to_numpy(dtype="int64")),
}

print(f"Training chunks : {len(df_example):,}")
print(f"Document chunks : {len(df_knowledge):,}")
print(f"Full (combined) : {len(df_full):,}")
# Out:
# Training chunks : 67,864
# Document chunks : 40,952
# Full (combined) : 108,816

# %% [markdown]
# ## 4. Encoding Function
#
# Takes a list of strings + a loaded model + tokenizer, returns a float32 numpy array of shape
# `(N, 768)` where each row is the `[CLS]` embedding of one chunk.
#
# Uses batched inference with `torch.no_grad()`. Moves tensors to GPU if available.

# %%
# This function is now in the rag.py file
import sys
sys.path.insert(0, str(Path("..").resolve()))
from rag import encode

# %% [markdown]
# ## 5. Build SBERT Indices
#
# Encodes all chunks with `all-mpnet-base-v2` using mean pooling, L2-normalises,
# and saves one `IndexIDMap(IndexFlatIP)` per split.

# %%
SBERT_HF_ID  = "sentence-transformers/all-mpnet-base-v2"

print(f"Loading {SBERT_HF_ID} ...")
sbert_tokenizer = AutoTokenizer.from_pretrained(SBERT_HF_ID)
sbert_model     = AutoModel.from_pretrained(SBERT_HF_ID).eval().to(device)
embed_dim       = sbert_model.config.hidden_size
print(f"Embedding dim: {embed_dim}  |  device: {device}\n")

for source_name, (texts, chunk_ids) in SOURCES.items():
    print(f"Encoding [{source_name}] {len(texts):,} chunks ...", flush=True)
    vectors = encode(texts, sbert_model, sbert_tokenizer,
                     batch_size=64, max_length=128, use_mean_pool=True)
    faiss.normalize_L2(vectors)

    inner = faiss.IndexFlatIP(embed_dim)
    index = faiss.IndexIDMap(inner)
    index.add_with_ids(vectors, chunk_ids)

    out_path = INDEX_DIR / f"vdb_{source_name}.faiss"
    faiss.write_index(index, str(out_path))
    print(f"  → saved {index.ntotal:,} vectors to {out_path.relative_to(INDEX_DIR)}\n")

del sbert_model
if device.type == "cuda":
    torch.cuda.empty_cache()
print("Done.")
# Out:
# Loading sentence-transformers/all-mpnet-base-v2 ...
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Embedding dim: 768  |  device: cpu
#
# Encoding [example] 67,864 chunks ...
# Encoding:   1%|          | 6/1061 [00:18<53:48,  3.06s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 11
#       9 for source_name, (texts, chunk_ids) in SOURCES.items():
#      10     print(f"Encoding [{source_name}] {len(texts):,} chunks ...", flush=True)
# ---> 11     vectors = encode(texts, sbert_model, sbert_tokenizer,
# ...

# %% [markdown]
# ## 6. Save Shared Lookup Tables
#
# Three JSON files mapping `chunk_id → text`, shared across all indices.

# %%
def _save_lookup(path, ids, texts):
    d = {str(cid): text for cid, text in zip(ids, texts)}
    with open(path, "w") as f:
        json.dump(d, f, ensure_ascii=False, indent=2)
    print(f"Saved {Path(path).relative_to(INDEX_DIR)}  ({len(d):,} entries)")

_save_lookup(INDEX_DIR / "lookup_example.json",  df_example["chunk_id"],  df_example["text"])
_save_lookup(INDEX_DIR / "lookup_knowledge.json", df_knowledge["chunk_id"], df_knowledge["text"])
_save_lookup(INDEX_DIR / "lookup_full.json",      df_full["chunk_id"],      df_full["text"])

# %% [markdown]
# ## 7. Sanity Check
#
# Load the sbert index and run sample queries to verify end-to-end retrieval quality.
# With sbert embeddings, similarity scores should vary meaningfully (e.g. 0.5–0.95).

# %%
SIMILARITY_THRESHOLD = 0.5  # sbert embeddings are well-separated — 0.5 is a reasonable floor

test_index = faiss.read_index(str(INDEX_DIR / "vdb_example.faiss"))
with open(INDEX_DIR / "lookup_example.json") as f:
    lookup = json.load(f)

print(f"Index: sbert/vdb_example.faiss  ({test_index.ntotal:,} vectors)")

# Reload sbert — was deleted after building indices to free GPU memory
SBERT_HF_ID     = "sentence-transformers/all-mpnet-base-v2"
sbert_tokenizer = AutoTokenizer.from_pretrained(SBERT_HF_ID)
sbert_model     = AutoModel.from_pretrained(SBERT_HF_ID).eval().to(device)

def query_index(tweet_text, k=5, threshold=SIMILARITY_THRESHOLD):
    vec = encode([tweet_text], sbert_model, sbert_tokenizer, batch_size=1, use_mean_pool=True)
    faiss.normalize_L2(vec)
    scores, ids = test_index.search(vec, k)
    return [
        (lookup[str(ids[0][i])], float(scores[0][i]))
        for i in range(k)
        if ids[0][i] != -1 and scores[0][i] >= threshold
    ]

queries = [
    ("HATE",     "jews are now in full control : canadian man goes to jail for posting on white nationalist websites"),
    ("HATE",     "i dont like neggers"),
    ("NOT HATE", "can they breath fire and have scaly skin ?"),
    ("NOT HATE", "Charges in deadly wreck that killed 5 motorcyclists ."),
]

print()
for label, tweet in queries:
    print(f"[{label}] {tweet}")
    hits = query_index(tweet)
    if hits:
        for text, score in hits:
            print(f"  {score:.3f}  {text[:100]}")
    else:
        print("  (no results above threshold)")
    print()
# Out:
# Index: sbert/vdb_example.faiss  (67,864 vectors)
#
# [HATE] jews are now in full control : canadian man goes to jail for posting on white nationalist websites
# Encoding: 100%|██████████| 1/1 [00:00<00:00,  5.87it/s]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
